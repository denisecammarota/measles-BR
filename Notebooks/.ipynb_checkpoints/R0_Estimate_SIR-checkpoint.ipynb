# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
from epiweeks import Year
from sklearn.linear_model import LinearRegression
#import geopandas as gpd
#import geobr

# %%
sys.path.append('..')

# %% [markdown]
# ## Manacapuru

# %%
res_path = '../Data/analyzed/res_epi_curve_130250.csv'
df_res = pd.read_csv(res_path)

years = (df_res['DATA_EPI'].astype(str).str[:4]).unique()
years_int = [eval(i) for i in years]

year_week_epi = []
for year in years_int:
    nweeks_year = Year(year).totalweeks()
    weeks_year = list(np.arange(1,nweeks_year+1))
    weeks_year = [str(x) for x in weeks_year]
    weeks_year = ['0'+x if len(x) == 1 else x for x in weeks_year]
    weeks_year = [str(year)+'-'+x for x in weeks_year]
    year_week_epi.extend(weeks_year)

cases_week_epi = list(np.zeros(len(year_week_epi)))
df_aux = pd.DataFrame({'DATA_EPI': year_week_epi, 'CASO': cases_week_epi})
df_res = df_res.merge(df_aux,how = 'right', on = 'DATA_EPI' )

df_res['CASES_RES'] = df_res['CASO_x']
df_res = df_res.drop(columns = ['Unnamed: 0', 'CASO_x','CASO_y'])
df_res = df_res.fillna(0)

# %%
df_res['CASES_RES_N'] = (df_res['CASES_RES']/99613)

# %%
x = range(len(df_res['DATA_EPI']))
plt.plot(x, df_res['CASES_RES'],'-o', label = 'Residents', linewidth = 2)
x_ticks = np.arange(0,len(x),3)
plt.xticks(x_ticks, df_res['DATA_EPI'][x_ticks], rotation = 45,fontsize = 9)
plt.title('Measles Cases in Manacaparu (AM)')
plt.show()

C = df_res['CASES_RES'].sum()

# %%
df_res['CASES_RES'].sum()
# Out:
# 946.0

# %%
df_res
# Out:
#    DATA_EPI  CASES_RES  CASES_RES_N
# 0   2018-01        0.0     0.000000
# 1   2018-02        0.0     0.000000
# 2   2018-03        0.0     0.000000
# 3   2018-04        0.0     0.000000
# 4   2018-05        0.0     0.000000
# 5   2018-06        0.0     0.000000
# 6   2018-07        0.0     0.000000
# 7   2018-08        0.0     0.000000
# 8   2018-09        0.0     0.000000
# 9   2018-10        0.0     0.000000
# 10  2018-11        0.0     0.000000
# 11  2018-12        0.0     0.000000
# 12  2018-13        0.0     0.000000
# 13  2018-14        2.0     0.000020
# 14  2018-15        0.0     0.000000
# 15  2018-16        0.0     0.000000
# 16  2018-17        1.0     0.000010
# 17  2018-18        5.0     0.000050
# 18  2018-19        7.0     0.000070
# 19  2018-20       11.0     0.000110
# 20  2018-21       51.0     0.000512
# 21  2018-22       44.0     0.000442
# 22  2018-23       98.0     0.000984
# 23  2018-24       89.0     0.000893
# 24  2018-25      112.0     0.001124
# 25  2018-26       79.0     0.000793
# 26  2018-27       95.0     0.000954
# 27  2018-28       60.0     0.000602
# 28  2018-29       61.0     0.000612
# 29  2018-30       47.0     0.000472
# 30  2018-31       41.0     0.000412
# 31  2018-32       37.0     0.000371
# 32  2018-33       42.0     0.000422
# 33  2018-34       26.0     0.000261
# 34  2018-35       12.0     0.000120
# 35  2018-36       10.0     0.000100
# 36  2018-37        4.0     0.000040
# 37  2018-38        4.0     0.000040
# 38  2018-39        1.0     0.000010
# 39  2018-40        1.0     0.000010
# 40  2018-41        2.0     0.000020
# 41  2018-42        2.0     0.000020
# 42  2018-43        0.0     0.000000
# 43  2018-44        0.0     0.000000
# 44  2018-45        2.0     0.000020
# 45  2018-46        0.0     0.000000
# 46  2018-47        0.0     0.000000
# 47  2018-48        0.0     0.000000
# 48  2018-49        0.0     0.000000
# 49  2018-50        0.0     0.000000
# 50  2018-51        0.0     0.000000
# 51  2018-52        0.0     0.000000

# %%
df_fit = df_res[17:23]
df_fit['DAYS'] = [0,7,14,21,28,35]
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_14492\3372236209.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fit['DAYS'] = [0,7,14,21,28,35]

# %%
time = np.array(df_fit['DAYS'])
cases = np.array(df_fit['CASES_RES_N'])
logcases = np.log(cases)

# %%
time = time.reshape((-1, 1))
model = LinearRegression().fit(time, logcases)

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: -10.032849561426751
# slope: [0.08949558]

# %%
slope = model.coef_
intercept = model.intercept_

# %%
R0 = 2*slope[0]/((946.0/99613)*(1/7))
print('R0 = ', R0)
# Out:
# R0 =  131.93332173529637

# %%
S0 = 1/(R0) + (946/99613)/2

# %%
print('S0 = ',S0)
print('S0*N =',S0*99613)
print('C*N = ', C)
# Out:
# S0 =  0.012327962531582243
# S0*N = 1228.025331658502
# C*N =  946.0

# %%
plt.plot(time,cases*99613,'-o')
plt.plot(time,99613*np.exp(slope*time + intercept))

# %% [markdown]
# ## Manaus

# %%
N = 2255903

res_path = '../Data/analyzed/res_epi_curve_130260.csv'
df_res = pd.read_csv(res_path)

years = (df_res['DATA_EPI'].astype(str).str[:4]).unique()
years_int = [eval(i) for i in years]

year_week_epi = []
for year in years_int:
    nweeks_year = Year(year).totalweeks()
    weeks_year = list(np.arange(1,nweeks_year+1))
    weeks_year = [str(x) for x in weeks_year]
    weeks_year = ['0'+x if len(x) == 1 else x for x in weeks_year]
    weeks_year = [str(year)+'-'+x for x in weeks_year]
    year_week_epi.extend(weeks_year)

cases_week_epi = list(np.zeros(len(year_week_epi)))
df_aux = pd.DataFrame({'DATA_EPI': year_week_epi, 'CASO': cases_week_epi})
df_res = df_res.merge(df_aux,how = 'right', on = 'DATA_EPI' )

df_res['CASES_RES'] = df_res['CASO_x']
df_res = df_res.drop(columns = ['Unnamed: 0', 'CASO_x','CASO_y'])
df_res = df_res.fillna(0)

df_res['CASES_RES_N'] = (df_res['CASES_RES']/N)

x = range(len(df_res['DATA_EPI']))
plt.plot(x, df_res['CASES_RES'],'-o', label = 'Residents', linewidth = 2)
x_ticks = np.arange(0,len(x),7)
plt.xticks(x_ticks, df_res['DATA_EPI'][x_ticks], rotation = 45,fontsize = 9)
plt.title('Measles Cases in Manaus(AM)')
plt.show()

C = df_res['CASES_RES'].sum()

# %%
df_fit = df_res[8:24]
df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_14492\2553293676.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)

# %%
time = np.array(df_fit['DAYS'])
cases = np.array(df_fit['CASES_RES_N'])
logcases = np.log(cases)

time = time.reshape((-1, 1))
model = LinearRegression().fit(time, logcases)

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: -13.072022015605564
# slope: [0.04116122]

# %%
slope = model.coef_
intercept = model.intercept_

R0 = 2*slope[0]/((C/N)*(1/7))
print('R0 = ', R0)

S0 = 1/(R0) + (C/N)/2
print('S0 = ',S0)
print('S0*N =',S0*N)
print('C*N = ', C)
# Out:
# R0 =  181.46007882294074
# S0 =  0.007098688221955313
# S0*N = 16013.952055973657
# C*N =  7164.0

# %%
plt.plot(time,cases*N,'-o')
plt.plot(time,N*np.exp(slope*time + intercept))

# %% [markdown]
# ## Francisco Morato

# %%
N = 165139

res_path = '../Data/analyzed/res_epi_curve_351630.csv'
df_res = pd.read_csv(res_path)

years = (df_res['DATA_EPI'].astype(str).str[:4]).unique()
years_int = [eval(i) for i in years]

year_week_epi = []
for year in years_int:
    nweeks_year = Year(year).totalweeks()
    weeks_year = list(np.arange(1,nweeks_year+1))
    weeks_year = [str(x) for x in weeks_year]
    weeks_year = ['0'+x if len(x) == 1 else x for x in weeks_year]
    weeks_year = [str(year)+'-'+x for x in weeks_year]
    year_week_epi.extend(weeks_year)

cases_week_epi = list(np.zeros(len(year_week_epi)))
df_aux = pd.DataFrame({'DATA_EPI': year_week_epi, 'CASO': cases_week_epi})
df_res = df_res.merge(df_aux,how = 'right', on = 'DATA_EPI' )

df_res['CASES_RES'] = df_res['CASO_x']
df_res = df_res.drop(columns = ['Unnamed: 0', 'CASO_x','CASO_y'])
df_res = df_res.fillna(0)

df_res['CASES_RES_N'] = (df_res['CASES_RES']/N)

x = range(len(df_res['DATA_EPI']))
plt.plot(x, df_res['CASES_RES'],'-o', label = 'Residents', linewidth = 2)
x_ticks = np.arange(0,len(x),7)
plt.xticks(x_ticks, df_res['DATA_EPI'][x_ticks], rotation = 45,fontsize = 9)
plt.title('Measles Cases in Francisco Morato (SP)')
plt.show()

C = df_res['CASES_RES'].sum()

# %%
df_fit = df_res[28:33]
df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_14492\2599121108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)

# %%
time = np.array(df_fit['DAYS'])
cases = np.array(df_fit['CASES_RES_N'])
logcases = np.log(cases)

time = time.reshape((-1, 1))
model = LinearRegression().fit(time, logcases)

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: -10.238092245507126
# slope: [0.06628945]

# %%
slope = model.coef_
intercept = model.intercept_

R0 = 2*slope[0]/((C/N)*(1/7))
print('R0 = ', R0)

S0 = 1/(R0) + (C/N)/2
print('S0 = ',S0)
print('S0*N =',S0*N)
print('C*N = ', C)
# Out:
# R0 =  241.35059678935482
# S0 =  0.006065972780078537
# S0*N = 1001.7286789293895
# C*N =  635.0

# %%
plt.plot(time,cases*N,'-o')
plt.plot(time,N*np.exp(slope*time + intercept))

# %% [markdown]
# ## Sao Paulo

# %%
N = 11451245

res_path = '../Data/analyzed/res_epi_curve_355030.csv'
df_res = pd.read_csv(res_path)

years = (df_res['DATA_EPI'].astype(str).str[:4]).unique()
years_int = [eval(i) for i in years]

year_week_epi = []
for year in years_int:
    nweeks_year = Year(year).totalweeks()
    weeks_year = list(np.arange(1,nweeks_year+1))
    weeks_year = [str(x) for x in weeks_year]
    weeks_year = ['0'+x if len(x) == 1 else x for x in weeks_year]
    weeks_year = [str(year)+'-'+x for x in weeks_year]
    year_week_epi.extend(weeks_year)

cases_week_epi = list(np.zeros(len(year_week_epi)))
df_aux = pd.DataFrame({'DATA_EPI': year_week_epi, 'CASO': cases_week_epi})
df_res = df_res.merge(df_aux,how = 'right', on = 'DATA_EPI' )

df_res['CASES_RES'] = df_res['CASO_x']
df_res = df_res.drop(columns = ['Unnamed: 0', 'CASO_x','CASO_y'])
df_res = df_res.fillna(0)

df_res['CASES_RES_N'] = (df_res['CASES_RES']/N)

x = range(len(df_res['DATA_EPI']))
plt.plot(x, df_res['CASES_RES'],'-o', label = 'Residents', linewidth = 2)
x_ticks = np.arange(0,len(x),5)
plt.xticks(x_ticks, df_res['DATA_EPI'][x_ticks], rotation = 45,fontsize = 9)
plt.title('Measles Cases in Sao Paulo (SP)')
plt.xlim((370,440))
plt.show()

C = df_res['CASES_RES'].sum()

# %%
df_fit = df_res[384:393]
df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_14492\2023701238.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)

# %%
time = np.array(df_fit['DAYS'])
cases = np.array(df_fit['CASES_RES_N'])
logcases = np.log(cases)

time = time.reshape((-1, 1))
model = LinearRegression().fit(time, logcases)

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: -13.894983403014185
# slope: [0.06785826]

# %%
slope = model.coef_
intercept = model.intercept_

R0 = 2*slope[0]/((C/N)*(1/7))
print('R0 = ', R0)

S0 = 1/(R0) + (C/N)/2
print('S0 = ',S0)
print('S0*N =',S0*N)
print('C*N = ', C)
# Out:
# R0 =  1105.1261227554205
# S0 =  0.001334696354329866
# S0*N = 15283.934954038106
# C*N =  9844.0

# %%
plt.plot(time,cases*N,'-o')
plt.plot(time,N*np.exp(slope*time + intercept))

# %% [markdown]
# ## Rio de Janeiro

# %%
N = 6211423

res_path = '../Data/analyzed/res_epi_curve_330455.csv'
df_res = pd.read_csv(res_path)

years = (df_res['DATA_EPI'].astype(str).str[:4]).unique()
years_int = [eval(i) for i in years]

year_week_epi = []
for year in years_int:
    nweeks_year = Year(year).totalweeks()
    weeks_year = list(np.arange(1,nweeks_year+1))
    weeks_year = [str(x) for x in weeks_year]
    weeks_year = ['0'+x if len(x) == 1 else x for x in weeks_year]
    weeks_year = [str(year)+'-'+x for x in weeks_year]
    year_week_epi.extend(weeks_year)

cases_week_epi = list(np.zeros(len(year_week_epi)))
df_aux = pd.DataFrame({'DATA_EPI': year_week_epi, 'CASO': cases_week_epi})
df_res = df_res.merge(df_aux,how = 'right', on = 'DATA_EPI' )

df_res['CASES_RES'] = df_res['CASO_x']
df_res = df_res.drop(columns = ['Unnamed: 0', 'CASO_x','CASO_y'])
df_res = df_res.fillna(0)

df_res['CASES_RES_N'] = (df_res['CASES_RES']/N)

x = range(len(df_res['DATA_EPI']))
plt.plot(x, df_res['CASES_RES'],'-o', label = 'Residents', linewidth = 2)
x_ticks = np.arange(0,len(x),10)
plt.xticks(x_ticks, df_res['DATA_EPI'][x_ticks], rotation = 45,fontsize = 9)
plt.title('Measles Cases in Rio de Janeiro (RJ)')
plt.xlim((230,300))
plt.show()

C = df_res['CASES_RES'].sum()

# %% [markdown]
# ## Belem

# %%
N = 1506420

res_path = '../Data/analyzed/res_epi_curve_150140.csv'
df_res = pd.read_csv(res_path)
years = (df_res['DATA_EPI'].astype(str).str[:4]).unique()
years_int = [eval(i) for i in years]

year_week_epi = []
for year in years_int:
    nweeks_year = Year(year).totalweeks()
    weeks_year = list(np.arange(1,nweeks_year+1))
    weeks_year = [str(x) for x in weeks_year]
    weeks_year = ['0'+x if len(x) == 1 else x for x in weeks_year]
    weeks_year = [str(year)+'-'+x for x in weeks_year]
    year_week_epi.extend(weeks_year)

cases_week_epi = list(np.zeros(len(year_week_epi)))
df_aux = pd.DataFrame({'DATA_EPI': year_week_epi, 'CASO': cases_week_epi})
df_res = df_res.merge(df_aux,how = 'right', on = 'DATA_EPI' )

df_res['CASES_RES'] = df_res['CASO_x']
df_res = df_res.drop(columns = ['Unnamed: 0', 'CASO_x','CASO_y'])
df_res = df_res.fillna(0)

df_res['CASES_RES_N'] = (df_res['CASES_RES']/N)

x = range(len(df_res['DATA_EPI']))
plt.plot(x, df_res['CASES_RES'],'-o', label = 'Residents', linewidth = 2)
x_ticks = np.arange(0,len(x),10)
plt.xticks(x_ticks, df_res['DATA_EPI'][x_ticks], rotation = 45,fontsize = 9)
plt.title('Measles Cases in Belem (PR)')
plt.xlim((120,200))
plt.show()

C = df_res['CASES_RES'].sum()

# %%
df_fit = df_res[144:160]
df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_14492\1736739613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fit['DAYS'] = np.arange(0,df_fit.shape[0]*7,7)

# %%
time = np.array(df_fit['DAYS'])
cases = np.array(df_fit['CASES_RES_N'])
logcases = np.log(cases)

time = time.reshape((-1, 1))
model = LinearRegression().fit(time, logcases)

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: -13.071111759112517
# slope: [0.03133133]

# %%
slope = model.coef_
intercept = model.intercept_

R0 = 2*slope[0]/((C/N)*(1/7))
print('R0 = ', R0)

S0 = 1/(R0) + (C/N)/2
print('S0 = ',S0)
print('S0*N =',S0*N)
print('C*N = ', C)
# Out:
# R0 =  459.50906503129386
# S0 =  0.0026535261606726993
# S0*N = 3997.3248789605677
# C*N =  1438.0

# %%
plt.plot(time,cases*N,'-o')
plt.plot(time,N*np.exp(slope*time + intercept))
